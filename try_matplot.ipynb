# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
plt.show()

# %%
p_x = np.random.rand(100)
p_y = np.random.rand(100)
plt.scatter(p_x, p_y)
plt.show()

# %%
data = np.random.randn(100000)
plt.hist(data)
plt.show()

# %%
data
# Out:
# array([-1.13560205,  2.177872  , -0.50763795, ..., -1.04527542,
#        -0.1154487 , -0.30521394])

# %%
np.average(data)
# Out:
# -0.004048672189077346

# %%
fig.savefig('test3.png') # 画像で保存

# %%
left = np.array([1, 2, 3, 4, 5])
height = np.array([100, 2000, 370, 40, 850])
plt.bar(left, height, color="#FF5B70", edgecolor="#CC4959", linewidth=4, align="center")
plt.title("bar graph for exercise")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(True)
